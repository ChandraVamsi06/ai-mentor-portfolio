# %% [markdown]
# <a href="https://colab.research.google.com/github/ChandraVamsi06/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the foundational to strategic skills needed for successful AI implementation:
#
# *   **1. Data & Infrastructure:** The foundational layer focusing on robust data acquisition, cleaning, storage, and the underlying computational infrastructure (e.g., cloud platforms, specialized hardware).
# *   **2. Machine Learning Algorithms & Models:** The core layer involving the development, training, and deployment of various machine learning algorithms, deep learning models, and other AI techniques.
# *   **3. Domain Expertise:** Integrating AI solutions with specific industry knowledge and subject matter expertise to define problems, interpret results, and ensure relevance.
# *   **4. Human-AI Interaction, Ethics & Business Value:** The top layer emphasizing responsible AI design, user experience, ethical considerations, and aligning AI initiatives with strategic business goals to deliver tangible value and impact.
